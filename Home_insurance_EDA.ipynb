# %% [markdown]
# Step 1: Read csv Data--

# %%
import pandas as pd

df = pd.read_csv(r"D:\home_insurance_dataset.csv")
df
# Out:
#      Policy_ID  Home_Value  Home_Age    Location Coverage_Type Claim_History  \
# 0            1     6923388        24  Semi-Urban         Basic            No
# 1            2     7050634        14       Urban       Premium           Yes
# 2            3     4804572        32       Urban       Premium            No
# 3            4     2734489        46  Semi-Urban         Basic            No
# 4            5     7704212        43       Urban       Premium           Yes
# ..         ...         ...       ...         ...           ...           ...
# 995        996     9236347        16       Urban       Premium           Yes
# 996        997     9360935        42       Urban       Premium            No
# 997        998     8167105        36       Rural      Standard            No
# 998        999     3194946        30  Semi-Urban      Standard           Yes
# 999       1000     4729215        18       Rural         Basic            No
#
#     Risk_Rating  Premium_Amount
# 0          High       16861.388
# 1           Low       18011.634
# 2        Medium       20264.572
# 3           Low       16425.489
# 4           Low       24798.212
# ..          ...             ...
# 995      Medium       20571.347
# 996      Medium       26843.935
# 997         Low       20907.105
# 998      Medium       14132.946
# 999      Medium       13081.215
#
# [1000 rows x 8 columns]

# %% [markdown]
# Step 2: Understand Dataset Structure--

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Policy_ID       1000 non-null   int64
#  1   Home_Value      1000 non-null   int64
#  2   Home_Age        1000 non-null   int64
#  3   Location        1000 non-null   object
#  4   Coverage_Type   1000 non-null   object
#  5   Claim_History   1000 non-null   object
#  6   Risk_Rating     1000 non-null   object
#  7   Premium_Amount  1000 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#          Policy_ID    Home_Value     Home_Age  Premium_Amount
# count  1000.000000  1.000000e+03  1000.000000     1000.000000
# mean    500.500000  5.164687e+06    25.378000    16098.309849
# std     288.819436  2.656073e+06    14.044941     4241.894584
# min       1.000000  5.393530e+05     1.000000     4049.087000
# 25%     250.750000  2.956326e+06    13.000000    13024.173500
# 50%     500.500000  5.097948e+06    25.000000    16051.649000
# 75%     750.250000  7.370068e+06    37.000000    19097.345250
# max    1000.000000  9.996563e+06    49.000000    27577.404000

# %% [markdown]
# Step 3: Identify Important Features--
# Common important features:
# - Home_Value
# - Home_Age
# - Location
# - Claim_History
# - Coverage_Type
# - Risk_Rating
# - Premium_Amount (Target)

# %% [markdown]
# Step 4: Handle Missing Values--

# %%
df.isnull().sum()
# Out:
# Policy_ID         0
# Home_Value        0
# Home_Age          0
# Location          0
# Coverage_Type     0
# Claim_History     0
# Risk_Rating       0
# Premium_Amount    0
# dtype: int64

# %%
df['Home_Age'].fillna(df['Home_Age'].median(),inplace=True)
df['Claim_History'].fillna(df['Claim_History'].mode()[0],inplace=True)
# Out:
# C:\Users\Seema\AppData\Local\Temp\ipykernel_10832\3621106571.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Home_Age'].fillna(df['Home_Age'].median(),inplace=True)
# C:\Users\Seema\AppData\Local\Temp\ipykernel_10832\3621106571.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Claim_History'].fillna(df['Claim_History'].mode()[0],inplace=True)

# %% [markdown]
# Step 5: Remove Duplicates--

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Exploratory Data Analysis(EDA)

# %% [markdown]
# Step 6: Univariate Analysis (Single Variable)
# - Premium Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Premium_Amount'],kde=True)
plt.show()

# %% [markdown]
# - Coverage Type Count

# %%
sns.countplot(x='Coverage_Type',data=df)
plt.show()

# %% [markdown]
# Step 7: Bivariate Analysis (Premium vs Other Features)
# - Premium vs Home Value

# %%
sns.scatterplot(x='Home_Value',y='Premium_Amount',data=df)
plt.show()

# %% [markdown]
# - Premium vs Claim History

# %%
sns.boxplot(x='Claim_History',y='Premium_Amount',data=df)
plt.show()

# %% [markdown]
# Step 8: Correlation Analysis--

# %%
plt.figure(figsize=(10,6))
numeric_df = df.select_dtypes(include='number')

sns.heatmap(numeric_df.corr(),annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Step 9: Create Subsets
# - Subset by Coverage Type

# %%
premium_coverage = df[df['Coverage_Type']== 'Premium']
basic_coverage = df[df['Coverage_Type'] == 'Basic']

# %% [markdown]
# - Subset by Risk Rating

# %%
high_risk = df[df['Risk_Rating'] == 'High']
loe_risk = df[df['Risk_Rating']== 'Low']

# %% [markdown]
# Step 10: Key Findings
# - Premium is strongly influenced by:
# Home value
# Claim history
# Risk rating
# Coverage type
#
# - Less impact:
# Home age
# Location (moderate)

# %% [markdown]
# What segment of customers are more likely to agree to pay a higher premium?
# What segments are we having difficulties with insurance payments?

# %% [markdown]
# Premium vs Home Value-

# %%
#Premium vs Home Value
sns.scatterplot(x='Home_Value',y='Premium_Amount',data=df)
plt.title('Premium vs Home Value')
plt.show()

# %% [markdown]
# Premium by Location-

# %%
sns.boxplot(x='Location',y='Premium_Amount',data=df)
plt.title('Premium by Location')
plt.show()

# %% [markdown]
# Premium by Claim History-

# %%
sns.boxplot(x='Claim_History',y='Premium_Amount',data=df)
plt.title("Impact of Claim History on Premium")
plt.show()
